# %%
import pickle

block_path = '/Users/kirtisoglu/GitHub/FalcomPlot/src/falcomplot/mapping/data/chicago.pkl'
with open(block_path, 'rb') as f:
    blocks = pickle.load(f)

print(type(blocks))
print(blocks.shape)
blocks.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 block_path = '/Users/kirtisoglu/GitHub/FalcomPlot/src/falcomplot/mapping/data/chicago.pkl'
#       4 with open(block_path, 'rb') as f:
# ----> 5     blocks = pickle.load(f)
#       7 print(type(blocks))
#       8 print(blocks.shape)
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
m = mapping.build_basemap(block_path)
m
